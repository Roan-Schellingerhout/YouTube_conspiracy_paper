# %%
import pandas as pd

# %%
pd.read_csv("neural_network.csv").sort_values("Accuracy", ascending=False).drop("Unnamed: 0", axis=1).head(10)
# Out:
#    Activation function  # of hidden layers  Neurons per layer  Accuracy  \
# 7             identity                  25                 10  0.864343
# 4             identity                  10                 10  0.864092
# 9             logistic                   1                  1  0.863340
# 26                tanh                  25                 20  0.862839
# 8             identity                  25                 20  0.862588
# 3             identity                  10                  1  0.859829
# 27                relu                   1                  1  0.858576
# 32                relu                  10                 20  0.857823
# 6             identity                  25                  1  0.857823
# 22                tanh                  10                 10  0.857322
#
#     Precision    Recall        F1
# 7    0.855376  0.883538  0.869229
# 4    0.876071  0.854545  0.865174
# 9    0.859209  0.875676  0.867364
# 26   0.849953  0.887961  0.868541
# 8    0.865716  0.864865  0.865290
# 3    0.871227  0.851106  0.861049
# 27   0.875447  0.842752  0.858788
# 32   0.892513  0.820147  0.854802
# 6    0.868104  0.850614  0.859270
# 22   0.860020  0.860442  0.860231

# %%
pd.read_csv("support-vector_machine.csv").sort_values("Accuracy", ascending=False).drop("Unnamed: 0", axis=1).head(10)
# Out:
#     Kernel      C  Accuracy  Precision    Recall        F1
# 10     rbf   10.0  0.888415   0.906858  0.870762  0.888443
# 11     rbf  100.0  0.883651   0.901790  0.866339  0.883709
# 9      rbf    1.0  0.873119   0.892252  0.854545  0.872992
# 7     poly  100.0  0.864845   0.906964  0.819165  0.860831
# 5     poly    1.0  0.861836   0.892178  0.829484  0.859689
# 6     poly   10.0  0.859829   0.905495  0.809828  0.854994
# 1   linear    1.0  0.855817   0.862823  0.853071  0.857919
# 2   linear   10.0  0.840020   0.846650  0.838329  0.842469
# 8      rbf    0.1  0.839017   0.833733  0.855037  0.844250
# 3   linear  100.0  0.830993   0.843513  0.821130  0.832171

# %%
pd.read_csv("logistic_regression.csv").sort_values("Accuracy", ascending=False).drop("Unnamed: 0", axis=1).head(10)
# Out:
#    Penalty   C     Solver  Accuracy  Precision    Recall        F1
# 23      l2  20       saga  0.871364   0.880881  0.864865  0.872799
# 2       l2  20  newton-cg  0.871113   0.880821  0.864373  0.872520
# 14      l2  20        sag  0.871113   0.880821  0.864373  0.872520
# 7       l2  10      lbfgs  0.870612   0.883392  0.859951  0.871514
# 13      l2  10        sag  0.869609   0.881228  0.860442  0.870711
# 1       l2  10  newton-cg  0.869609   0.881228  0.860442  0.870711
# 22      l2  10       saga  0.869609   0.881228  0.860442  0.870711
# 8       l2  20      lbfgs  0.869609   0.880462  0.861425  0.870840
# 24    none   1       saga  0.863591   0.874811  0.855037  0.864811
# 26    none  20       saga  0.863340   0.874748  0.854545  0.864529

# %%
pd.read_csv("k-nearest_neighbors.csv").sort_values("Accuracy", ascending=False).drop("Unnamed: 0", axis=1).head(10)
# Out:
#      K  Accuracy  Precision    Recall        F1
# 3    4  0.822217   0.822785  0.830467  0.826608
# 5    6  0.819458   0.813543  0.838329  0.825750
# 7    8  0.810181   0.796382  0.843735  0.819375
# 11  12  0.806670   0.785973  0.853563  0.818375
# 4    5  0.805416   0.753320  0.919902  0.828319
# 9   10  0.802658   0.784932  0.844717  0.813728
# 6    7  0.801655   0.755127  0.904668  0.823161
# 13  14  0.797141   0.771720  0.855528  0.811466
# 10  11  0.794885   0.756859  0.881081  0.814260
# 8    9  0.793882   0.753872  0.885012  0.814195

# %%
pd.read_csv("ridge_classification.csv").sort_values("Accuracy", ascending=False).drop("Unnamed: 0", axis=1).head(10)
# Out:
#        Solver  Alpha  Accuracy  Precision    Recall        F1
# 1        auto    1.0  0.868606   0.884087  0.854545  0.869065
# 5   sparse_cg    1.0  0.868606   0.884087  0.854545  0.869065
# 9         sag    1.0  0.868606   0.884087  0.854545  0.869065
# 0        auto    0.1  0.860582   0.867727  0.857494  0.862580
# 4   sparse_cg    0.1  0.860582   0.867727  0.857494  0.862580
# 8         sag    0.1  0.860331   0.867296  0.857494  0.862367
# 2        auto   10.0  0.833751   0.851434  0.816708  0.833710
# 6   sparse_cg   10.0  0.833751   0.851434  0.816708  0.833710
# 10        sag   10.0  0.833501   0.851358  0.816216  0.833417
# 3        auto  100.0  0.766800   0.810568  0.708600  0.756162
