# %%
import pyyoutube
import pandas as pd
from collections import defaultdict
from tqdm import notebook
import requests

from youtube_transcript_api import YouTubeTranscriptApi

# %%
keys = ["AIzaSyBHonuF98PzbYOg7Z1ZFnlAaHjl0Gh3Kjg",  
        "AIzaSyDvaaNTMomMcvGwcz-TrvdrgTlvk4TDAeg", 
        "AIzaSyDvD8rnCKonVOnWAtZCfAu22svlgY9dsuU",
        "AIzaSyA1tCsmnGtTrNLDW_SKyWkArihc3o-bCho",
        "AIzaSyDvk4LR8GYYEMtuKwCQWcVWgaBnY2ftW8A"] #roan.schellingerhout, xiodazer, roanspaypal, ronzijnsmurf, veilen

# %%
api = pyyoutube.Api(api_key=keys[0])

# %%
def update_key(api, key_list):
    current = key_list.index(api._api_key)
    print("Updating API key...")
    
    while current < len(key_list):
        api = pyyoutube.Api(api_key=key_list[current])
        
        try: # see if this key is functional
            api.get_channel_info(channel_id="UC0aanx5rpr7D1M7KCFYzrLQ")
            return api
        except: # if it's not, try the next one
            current += 1
    
    # if no key was functional, exit
    print("No keys remaining...")
    return None

# %%
def get_info(api, channel_id):
    """Get general info of a channel"""
    
    results = defaultdict(list)
    
    try:
        # Get the channel info from the API
        channel_by_id = api.get_channel_info(channel_id=channel_id)
        if not channel_by_id: # Channel no longer exists
            print(f"User {channel_id} not found")
            return None, api
    except Exception as e:
        if "quota" in str(e): # if the error was caused due to the quota-limit, refresh the key
            api = update_key(api, keys)
            channel_by_id = api.get_channel_info(channel_id=channel_id)
            if not channel_by_id: # Channel not found, even after key-refresh
                print(f"User {channel_id} not found")
                return None, api
        else: # e had a message, but it was about something else
            print(f"Skipping: {channel_id} due to {e}")
            return None, api
        
    if channel_by_id.items:
        c = channel_by_id.items[0].to_dict()
        results["channel"].append(channel_id)
        results["channel_description"].append(c["snippet"]["description"])
        results["country"].append(c["snippet"]["country"])
        results["keywords"].append(c["brandingSettings"]["channel"]["keywords"])
        results["uploads"].append(c["contentDetails"]["relatedPlaylists"]["uploads"])
                
        return results, api
    else:
        return None, api

# %%
get_info(api, "UCsXVk37bltHxD1rDPwtNM8Q")
# Out:
# (defaultdict(list,
#              {'channel': ['UCsXVk37bltHxD1rDPwtNM8Q'],
#               'channel_description': ['Videos explaining things with optimistic nihilism. \n\nWe are a small team who want to make science look beautiful. Because it is beautiful. \n\nCurrently we make one animation video per month. Follow us on Twitter, Facebook to get notified when a new one comes out.\n\nFAQ:\n \n- We do the videos with After Effects and Illustrator.'],
#               'country': ['DE'],
#               'keywords': ['Science universe space infographic evolution education funny death life history ebola Fermi'],
#               'uploads': ['UUsXVk37bltHxD1rDPwtNM8Q']}),
#  <pyyoutube.api.Api at 0x20f808b4f28>)

# %%
def get_uploads(api, channel_id, conspiracy, playlist_id, n):
    uploads = defaultdict(list)
    
    try:
        # Get the playlist info from the API
        ups = api.get_playlist_items(playlist_id = playlist_id, count = n)
        if not ups: # Playlist no longer exists
            print(f"User {channel_id} not found")
            return None, api
    except Exception as e:
        if "quota" in str(e): # if the error was caused due to the quota-limit, refresh the key
            api = update_key(api, keys)
            ups = api.get_playlist_items(playlist_id = playlist_id, count = n)
            if not ups: # Channel not found, even after key-refresh
                print(f"User {channel_id[0]} not found")
                return None, api
        else: # e had a message, but it was about something else
            print(f"Skipping: {channel_id[0]} due to an error (no uploads, timeout, etc.)")
            return None, api
        
    
    if ups.items:
        for up in ups.items:
            vid = up.to_dict()           
            uploads["channel"].append(vid["snippet"]["channelId"])
            uploads["video_id"].append(vid["contentDetails"]["videoId"])
            uploads["title"].append(vid["snippet"]["title"])
            uploads["description"].append(vid["snippet"]["description"])
            uploads["conspiracy"].append(conspiracy)

            # Add transcript
            
            text = ""
            
            try:
                text = " ".join([i["text"] for i in\
                                 YouTubeTranscriptApi.get_transcript(vid["contentDetails"]["videoId"])])
            except:
                pass
            
            uploads["transcript"].append(text)
            
            
        return uploads, api
    else:
        return None, api

# %%
# get_uploads(api, "UC0aanx5rpr7D1M7KCFYzrLQ", False, "UUsXVk37bltHxD1rDPwtNM8Q", 5)

# %%
df = pd.read_csv("../data/dataset_boolean.csv").drop("Unnamed: 0", axis=1)
df.head()
# Out:
#              Channel_name  Conspiracy                Channel_id LR
# 0            Simon Parkes        True  UCgzqRRDGThOlH4EHaqSXXPA  R
# 1                The Stoa       False  UCfI5jzpoUbwP4wkmQ6ZNqbA  C
# 2              X22 Report        True  UCKXM6nMVQW_VfjwqVAnxvdw  R
# 3              Ben Burgis       False  UCByZMNYpHFEetI0s3deYH2g  L
# 4  3D to 5D Consciousness        True  UC3VlH7lPbKlzVda5aJgyUvQ  R

# %%
def create_dicts(api, n):
    
    channels_dict = defaultdict(list)
    uploads_dict = defaultdict(list)

    # Go over each channel in the dataset
    for i in notebook.tqdm(df.iterrows(), total=len(df)):
        # Find channel information
        channel, new_api = get_info(api, i[1]["Channel_id"])
        
        # Refresh API if needed
        if api != new_api:
            api = new_api
            
        # If the channel was found, add its information
        if channel:
            for c in channel:
                channels_dict[c].append(channel[c][0])
                
            channels_dict["conspiracy"].append(i[1]["Conspiracy"])
                
            # Find uploads of the given channel
            uploads, new_api = get_uploads(api, channel["channel"], i[1]["Conspiracy"], channel["uploads"], n)
            if api != new_api:
                api = new_api
                   
        # If uploads have been found, add them
        if uploads:
            for j, upload in enumerate(uploads):
                for value in uploads[upload]:
                    uploads_dict[upload].append(value) 
        
    return channels_dict, uploads_dict

# %%
channels, uploads = create_dicts(api, 10)
# Out:
#   0%|          | 0/6881 [00:00<?, ?it/s]
# Skipping: UCFuuSJn_91xsrANbMd8h67g due to an error (no uploads, timeout, etc.)
# Skipping: UCpO8DrZ1mSasrH93Ml-Ay9g due to an error (no uploads, timeout, etc.)
# Skipping: UChnbPl3guXu81OXB__HAT-w due to an error (no uploads, timeout, etc.)
# Skipping: UCC2Zd5bz-rUnmdsEpkjkXBg due to an error (no uploads, timeout, etc.)
# Skipping: UC85FErR-Kn_IX-xrpBpIkMQ due to an error (no uploads, timeout, etc.)
# Skipping: UCVJ6bEJChervVShvOTG0qRw due to an error (no uploads, timeout, etc.)
# Skipping: UCFvub3YrEUoXl8aPHZBbHqw due to an error (no uploads, timeout, etc.)
# Skipping: UCLyV5MJZV-kXunNftlFif1A due to an error (no uploads, timeout, etc.)
# Skipping: UCGlLEGoGE1ZUAMQcUFNa8QQ due to an error (no uploads, timeout, etc.)
# Skipping: UC2D7vZh77B_dx4-c7o8KGWw due to an error (no uploads, timeout, etc.)
# Skipping: UCHAv1g2JODsrkUKfHh1nAwQ due to an error (no uploads, timeout, etc.)
# Skipping: UCFpvg5yg5fMda91yiI1owSQ due to an error (no uploads, timeout, etc.)
# Skipping: UCv6czyqlTA8Jyvf6m2AxlMA due to an error (no uploads, timeout, etc.)
# Skipping: UC9D0rTpWN8l9nHARrTXOHOQ due to an error (no uploads, timeout, etc.)
# Skipping: UCCzXaeRS9HFClFxcJS9VNKg due to an error (no uploads, timeout, etc.)
# Skipping: UCr7p9ZvcS4X9yPWWwEOra7A due to an error (no uploads, timeout, etc.)
# Skipping: UCbxcBH7Qjqwr7GXmyIXfKBA due to an error (no uploads, timeout, etc.)
# Skipping: UCSlFKVc8tufJ6gSzxk7v4vQ due to an error (no uploads, timeout, etc.)
# Skipping: UCpBI31GV3EOgYZ3iQJnu-qQ due to an error (no uploads, timeout, etc.)
# Skipping: UCg9rndIv5eCG1QgaV5cS_Ng due to an error (no uploads, timeout, etc.)
# Skipping: UCn371zWk5jljg-ycIXkEUSA due to an error (no uploads, timeout, etc.)
# Skipping: UCoNGo02Aai6VQotn-MNnbpw due to an error (no uploads, timeout, etc.)
# Skipping: UCJLTdZbZqbG-ieXXRXed5ww due to an error (no uploads, timeout, etc.)
# Skipping: UC9NQqMh0nfeqzPBrMOIGeoQ due to an error (no uploads, timeout, etc.)
# Skipping: UCmGPOCha9H7zvMBY4diKd6w due to an error (no uploads, timeout, etc.)
# Skipping: UCSwP0DhF6j6SKlfv0g0LlFw due to an error (no uploads, timeout, etc.)
# Skipping: UCdEfsAy6rUDPnm9HwKA_asg due to an error (no uploads, timeout, etc.)
# Skipping: UC5nKzWxYHmBkBIuGjArQ58w due to an error (no uploads, timeout, etc.)
# Skipping: UCoWe8JjDi-0wrdzo--2htHw due to an error (no uploads, timeout, etc.)
# Skipping: UCagZBmBgbRavytbIqn51teA due to an error (no uploads, timeout, etc.)
# Skipping: UCEUN17sMHfqxDrrOas56O6Q due to an error (no uploads, timeout, etc.)
# Skipping: UCvAvFl2OGsuDSoOo93Kd0nA due to an error (no uploads, timeout, etc.)
# Skipping: UCXvXcCB5PfRe8VTLMGoT3wg due to HTTPSConnectionPool(host='www.googleapis.com', port=443): Read timed out. (read timeout=10)
# Skipping: UCsqt1KoogkW9cWDwZyozYjw due to an error (no uploads, timeout, etc.)
# Skipping: UCVxYHHMK9DcnMup3t2A15qg due to an error (no uploads, timeout, etc.)
# Skipping: UCF93huicBH0WApJjUmrCxzg due to an error (no uploads, timeout, etc.)
# Skipping: UClF1pcKQ9lG6Ga8enc1JI1Q due to an error (no uploads, timeout, etc.)
# Skipping: UCoDPqV9aewgDwHTLut_hf2A due to an error (no uploads, timeout, etc.)
# Skipping: UCEdJ7XnXNekCKNaVBNCeigQ due to an error (no uploads, timeout, etc.)
# Skipping: UCFyLpcPQTl8x0P5bWuJUJwA due to an error (no uploads, timeout, etc.)
# Skipping: UCT5y7BAocgM-PeXpVCvyG4g due to an error (no uploads, timeout, etc.)
# Skipping: UCWzPpJysjD0Lum9Wa4Eu4Qw due to an error (no uploads, timeout, etc.)
# Skipping: UCPa80uB0JuGt0_OlW5M7NGQ due to an error (no uploads, timeout, etc.)
# Skipping: UCQuRRN1gEEoAoiG9N0btovA due to an error (no uploads, timeout, etc.)
# Skipping: UCaoBf4A_K7ZxkzXwXVDlAEQ due to an error (no uploads, timeout, etc.)
# Skipping: UC08uNkLOZwq0uqP558IWm4w due to an error (no uploads, timeout, etc.)
# Skipping: UC2uS6dXGXfwpw5usXlEO3ZQ due to an error (no uploads, timeout, etc.)
# Skipping: UC0hwSUgu98_uX_xuTELSKSg due to an error (no uploads, timeout, etc.)
# Skipping: UCZaDGL3gNyQUEl0HCoaFuaw due to an error (no uploads, timeout, etc.)
# Skipping: UCuB5EMQkJ2kofe9XtIsw8uQ due to an error (no uploads, timeout, etc.)
# Skipping: UCCy4tANRbtoDbwYUNnPhJlA due to an error (no uploads, timeout, etc.)
# Skipping: UC19J83LCkBL2KFPEtifwfJQ due to an error (no uploads, timeout, etc.)
# Skipping: UCF-Tr8q0Qf0LFBPkTq3JeGw due to an error (no uploads, timeout, etc.)
# Skipping: UCqSS_Gp6PX3BNbFdHCV-C6A due to an error (no uploads, timeout, etc.)
# Skipping: UCj6XJ1Lu22i8QsfntzT0hFQ due to an error (no uploads, timeout, etc.)
# Skipping: UC4WPFQWSvsDuUKsIjXrgCEw due to an error (no uploads, timeout, etc.)
# Skipping: UCDwm-QufrnPIasIxVaivpJg due to an error (no uploads, timeout, etc.)
# Skipping: UCA52Z_6XLO1E6_0MCwl6rRQ due to an error (no uploads, timeout, etc.)
# Skipping: UCt-Fkm7_om44GXa-0gVfjGw due to an error (no uploads, timeout, etc.)
# Skipping: UCsm7qkbhrUzI9ZAmMY5JuOw due to an error (no uploads, timeout, etc.)
# Skipping: UCN4Fn_GZpwLNsuk4ktL7A9A due to an error (no uploads, timeout, etc.)
# Skipping: UCgy53qI0TZckr6mOlK2PIrQ due to an error (no uploads, timeout, etc.)
# Skipping: UCl3QLbvveKAERl5g4JRgV5g due to an error (no uploads, timeout, etc.)
# Skipping: UC51MCIY0fWN8h172z_emmrQ due to an error (no uploads, timeout, etc.)
# Skipping: UCwWxvG1E5i05nwlavoC_VXQ due to an error (no uploads, timeout, etc.)
# Skipping: UCt6W-ymGWxP6YiBxPvvO3WQ due to an error (no uploads, timeout, etc.)
# Skipping: UCRiLfHKb4ZrzWdQkM-Wvo3w due to an error (no uploads, timeout, etc.)
# Skipping: UCDmOgumXzPp-JEMHuEqobqA due to an error (no uploads, timeout, etc.)
# Skipping: UCI6SNMx1V0L9lLpGaQFvztA due to an error (no uploads, timeout, etc.)
# Skipping: UCPj252nqvMnZ0FB-2buZUWQ due to an error (no uploads, timeout, etc.)
# Skipping: UCmtALVZjXFzb4v3fIXDmDyw due to an error (no uploads, timeout, etc.)
# Skipping: UCyjLGp8hQObJMm4lSQccjFw due to an error (no uploads, timeout, etc.)
# Skipping: UCFsFBNJmHUHNuTj_Hs2lNPQ due to an error (no uploads, timeout, etc.)
# Skipping: UCRHQiERYdyLgDZUhhQPzEAw due to an error (no uploads, timeout, etc.)
# Skipping: UCYQBujhx6vuwg-RuFcvmvnA due to an error (no uploads, timeout, etc.)
# Updating API key...
# Skipping: UCGFU6sxly61poDlB7rBFmNA due to an error (no uploads, timeout, etc.)
# Skipping: UCaRL0k3Wd-etzQpCQ_Ze01w due to an error (no uploads, timeout, etc.)
# Skipping: UCBl1XKAWVCP-MIYcU9Kz7MA due to an error (no uploads, timeout, etc.)
# Skipping: UC1owqZBjR5nMfYqJJRatRSw due to an error (no uploads, timeout, etc.)
# Skipping: UCi2o0utgfMe_FAmRNK_cpiw due to an error (no uploads, timeout, etc.)
# Skipping: UCcV1_PgN1Gxbo9j600C63wA due to an error (no uploads, timeout, etc.)
# Skipping: UCXIovaBdnA4UHdd-TZ-MqRg due to an error (no uploads, timeout, etc.)
# Skipping: UCcX9nxdblc19kfm5hqVfRBA due to an error (no uploads, timeout, etc.)
# Skipping: UCWIMUUnahjYH4Xq6FR0CaIA due to an error (no uploads, timeout, etc.)
# Skipping: UCI4KOWxnhaF6Vo1cMytOEuQ due to an error (no uploads, timeout, etc.)
# Skipping: UCif57-rdKCDOavdd3X8Ac7w due to an error (no uploads, timeout, etc.)
# Skipping: UC-kcAFi1PW0yR7xeKi9nA6Q due to an error (no uploads, timeout, etc.)
# Skipping: UCdqqrEJSiqOcpJHpask4nPQ due to an error (no uploads, timeout, etc.)
# Skipping: UCBmSbCRd_Jj5NgV3xTwrkHA due to an error (no uploads, timeout, etc.)
# Skipping: UCI5PoZJepN4QUBE2ZXXmNFw due to an error (no uploads, timeout, etc.)
# Skipping: UCJZlniPhTrQDlmyXhY-vlWw due to an error (no uploads, timeout, etc.)
# Skipping: UCoBaKYhMMbeaZyEMjBOMIyw due to an error (no uploads, timeout, etc.)
# Skipping: UC3_-GgP_2OpXohosehe0dkg due to an error (no uploads, timeout, etc.)
# Skipping: UCqKCjVqqn_bUGieUvtlF7Ew due to an error (no uploads, timeout, etc.)
# Skipping: UCwr45FKYTImalDE5aAoJBOQ due to an error (no uploads, timeout, etc.)
# Skipping: UCtG36aNGHp_H0NNOFr-B-Qg due to an error (no uploads, timeout, etc.)
# Skipping: UC71GX5rzz7hblP398iRV9Qg due to an error (no uploads, timeout, etc.)
# Skipping: UC7hGbKgaf_DK3w_gwQweICg due to an error (no uploads, timeout, etc.)
# Skipping: UCTLp7zZjQztDWdcgFEXctRA due to an error (no uploads, timeout, etc.)
# Skipping: UCYcr5ute99R-M86rfVyUUyQ due to an error (no uploads, timeout, etc.)
# Skipping: UC0rXIyKqsqD0wk-bYmp2x5Q due to an error (no uploads, timeout, etc.)
# Skipping: UC-jjYbFILVe9B6ab-RGOxpw due to an error (no uploads, timeout, etc.)
# Skipping: UCUJgjsbpV-LT096jkclIcCA due to an error (no uploads, timeout, etc.)
# Skipping: UCDWmp9u3xBGwFR1iEIeEyOg due to an error (no uploads, timeout, etc.)
# Skipping: UC5LYQ3rerGrxfSfDX7FAWdg due to an error (no uploads, timeout, etc.)
# Skipping: UCSwGdg2g8XpyBrXrIpuNQxg due to an error (no uploads, timeout, etc.)
# Skipping: UCfsgnppkYXuH9WbOXxUksQg due to an error (no uploads, timeout, etc.)
# Skipping: UCOANeOBcvtSOjrDaQgeChBA due to an error (no uploads, timeout, etc.)
# Skipping: UCRYK44h6TYZ3rxe-TMskyjA due to an error (no uploads, timeout, etc.)
# Skipping: UCLdcgni1mCq1OxUE3HIL8QQ due to an error (no uploads, timeout, etc.)
# Skipping: UCFfiBlGEdeZRaZsWV3v55fA due to an error (no uploads, timeout, etc.)
# Skipping: UCy2gOV0CFageToTKf_0sCqw due to an error (no uploads, timeout, etc.)
# Skipping: UC1KKegXvjrmbA5Jb-vRaFpg due to an error (no uploads, timeout, etc.)
# Skipping: UCiU2_P6Jmvym6KXYXTBfwPQ due to an error (no uploads, timeout, etc.)
# Skipping: UCsM7VR11bfAH5Dskiq4OBeg due to an error (no uploads, timeout, etc.)
# Skipping: UCUwXt2JjBYFykysPD0A6TFw due to an error (no uploads, timeout, etc.)
# Skipping: UCJqtn5Y2dTyoi0BnPgiAFOA due to an error (no uploads, timeout, etc.)
# Skipping: UCOrpD6svgE3L3CCnWk52JSg due to an error (no uploads, timeout, etc.)
# Skipping: UCShjBBUBfzeCR4iq9KpqXuw due to an error (no uploads, timeout, etc.)
# Skipping: UCRUhJlurBdyGwVyyaAdwS9w due to an error (no uploads, timeout, etc.)
# Skipping: UCkm28XYXc5pJmQ0yu_27DgQ due to an error (no uploads, timeout, etc.)
# Skipping: UCBgM8Esoy99vDtfbNPC2peA due to an error (no uploads, timeout, etc.)
# Skipping: UC4Cs3RuD_rfc_NE6vxjW1VQ due to an error (no uploads, timeout, etc.)
# Skipping: UCUfkV9hwXARgbbAQLRTqHyA due to an error (no uploads, timeout, etc.)
# Skipping: UCPhKAfBMRI-GDozE1ldix3A due to an error (no uploads, timeout, etc.)
# Skipping: UCegU7jX7WASluuwSPhU0PsA due to an error (no uploads, timeout, etc.)
# Skipping: UCzN6_jWdrUZYWheY6Ke8QCA due to an error (no uploads, timeout, etc.)
# Skipping: UC0qSkLTzo-40rA-WvzjTHDg due to an error (no uploads, timeout, etc.)
# Skipping: UC8-PsZi2Toy6R_UUjlL6-Og due to an error (no uploads, timeout, etc.)
# Skipping: UCPafUNC8c1NdTvWHcrSfa2w due to an error (no uploads, timeout, etc.)
# Skipping: UCYQlj5ERJzCylETSZlRUECQ due to an error (no uploads, timeout, etc.)
# Skipping: UCeivs1tenYht7iE7d4l11IA due to an error (no uploads, timeout, etc.)
# Skipping: UCEPvpsyv9H9oYJ8pVOBBmKw due to an error (no uploads, timeout, etc.)
# Skipping: UCK3ia4R2FHFnMP5WACPVHKA due to an error (no uploads, timeout, etc.)
# Skipping: UCcNAAX0RERd38v7NZlbL7Mg due to an error (no uploads, timeout, etc.)
# Skipping: UCeRoSynAadrkHrvuh7qT9xA due to an error (no uploads, timeout, etc.)
# Skipping: UC1k7PtkAP2bNq44CNFwRorA due to an error (no uploads, timeout, etc.)
# Skipping: UC9v4NE4NOJrNaY6vLjKA0oQ due to an error (no uploads, timeout, etc.)
# Skipping: UC8Ap0a-VRZALdStTdipHGuA due to an error (no uploads, timeout, etc.)
# Skipping: UCKAk5j6ElpeymRWONEbCcHg due to an error (no uploads, timeout, etc.)
# Skipping: UCcE169gw8kJCzyCJZXb7DQw due to an error (no uploads, timeout, etc.)
# Skipping: UCPZiqlNI3RLyF47QTdq93GQ due to an error (no uploads, timeout, etc.)
# Skipping: UCarEovlrD9QY-fy-Z6apIDQ due to an error (no uploads, timeout, etc.)

# %%
channel_df = pd.DataFrame(channels)

channel_df.to_csv("../data/channels.csv")

# %%
uploads_df = pd.DataFrame(uploads)

uploads_df.to_csv("../data/uploads.csv")

# %%
import pickle

with open('../data/uploads.pickle', 'wb') as handle:
    pickle.dump(uploads_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
uploads_df
# Out:
#                         channel     video_id  \
# 0      UCgzqRRDGThOlH4EHaqSXXPA  Eve8U63jOCA
# 1      UCgzqRRDGThOlH4EHaqSXXPA  T24xqK23NPk
# 2      UCgzqRRDGThOlH4EHaqSXXPA  IJAR8FYdDcE
# 3      UCgzqRRDGThOlH4EHaqSXXPA  NJej_CUkV8E
# 4      UCgzqRRDGThOlH4EHaqSXXPA  as9IEvaC9XA
# ...                         ...          ...
# 65679  UCgRvm1yLFoaQKhmaTqXk9SA  tt6yWP2VWOU
# 65680  UCgRvm1yLFoaQKhmaTqXk9SA  t7pmHD8rqOA
# 65681  UCgRvm1yLFoaQKhmaTqXk9SA  K7pzjFOe7X0
# 65682  UCgRvm1yLFoaQKhmaTqXk9SA  KpYxFouaTvk
# 65683  UCgRvm1yLFoaQKhmaTqXk9SA  BiulFh5uAyM
#
#                                                    title  \
# 0                                    16th January Update
# 1                                    13th January Update
# 2                12th January Second Update Current News
# 3                11th January Second Update Current News
# 4                       11th January Update Current News
# ...                                                  ...
# 65679  New Zealand's Push for Gun Reform, Explained |...
# 65680  The Rise and Fall of Myanmar’s Aung San Suu Ky...
# 65681  Spain's Plan to Quit the Coal Industry Explain...
# 65682  How Costa Rica Avoided Cold War Violence | Now...
# 65683  Trump’s Historic 'National Emergency’ Explaine...
#
#                                              description  conspiracy  \
# 0      www.simonparkes.org\n\nTelegram:\nhttps://t.me...        True
# 1      Bitchute Channel:\nhttps://www.bitchute.com/si...        True
# 2      To Join Connecting Consciousness:\nhttps://con...        True
# 3      www.simonparkes.org\n\nTo Join Connecting Cons...        True
# 4      www.simonparkes.org\n\nTo Join Connecting Cons...        True
# ...                                                  ...         ...
# 65679  New Zealand is making some big changes. Their ...       False
# 65680  A non-violent freedom fighter? A war crimes ap...       False
# 65681  Climate change is happening. And one industry ...       False
# 65682  Costa Rica has sometimes been called “the Swit...       False
# 65683  President Donald Trump has declared a national...       False
#
#                                               transcript
# 0      hello and just to let you know that i'm doing ...
# 1      hello and welcome to another update it's the 1...
# 2      hello and just a another quick update just to ...
# 3      hello uh just a very very very quick update it...
# 4      hello and welcome to a sort of flying update i...
# ...                                                  ...
# 65679  New Zealand is making some big changes. [ARDEN...
# 65680  A non-violent freedom fighter?  War crimes apo...
# 65681  Climate change is happening. And one industry ...
# 65682  Costa Rica has sometimes been called  “the Swi...
# 65683  What you’re about to see… is a historic moment...
#
# [65684 rows x 6 columns]
